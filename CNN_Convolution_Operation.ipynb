# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKPARATKAR/DEEP-LEARNING-WORK/blob/main/CNN_Convolution_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CNN-**
#
# CNN works better on image data.CNN is inspired from visual cortex of human beings.CNN has convolutional layer , pooling layer and fully connected layer(Dense Layer).
#
# In CNN architecture,initial layers finds out the premitive features like edges , and as you go ahead in CNN neteork,you create more complex features and at the end we perform taks like object detection and object classification.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Basics Of Images-**
#
# Grayscale Images- It is a black and images
#
# RGB Images - Coloured images.
#
# Grayscale image is made up of 2d pixels grid. We have images  in 28 * 28 pixels like this.There is only one channel in grayscale image.
#
# ![1.jpg](data:image/jpeg;base64,...)
#
# RGB images are made up of 3d pixels grid.Any RGB image is made up of combination 3 colors,red-gree and blue.Each color has its own chanel which means RGB images have 3 channels of each color.RGB image is represented as 228 * 228 * 3 , here 3 because there are three channels.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Convolution Operation-**
#
# Edges in an image is nothing but the change in intensity.Below is the example of horizontal edge detector.If we change the filter/kernel values then we will get the vertical edge detector. If you want to detect the slant edges,then for that we have some different kind of filters. We have top filter,bottom filter,left filter,right filter etc to detect different types edges in an image.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The values of filers , we will get tk know at time of training only. We dont have to generate the filter.FIlter values are decided by CNN at the time of training like weight and bias values are decided at the time of training in ANN.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Above is the output f convolution process on Mnist dataset with left edge filter which means this filter will tell the left edges.In output of the convolution process,we got two colors red and blue. Red color is actual red left edge detected and blue is also the edge but not left edge.What we do here is we apply Relu activation on output,all the values which are negative will become 0 and only positive i.e. red portion values will remain and as a result we get left edges in the image.

# %% [markdown]
# **Convolution on RGB image-**
#
# RGB image has 3 channels that is different channel for different color.So we will also require 3 chanel filter. We can consider the RGB image and filer as cuboid of 3 dimensions.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Here we performing convolution of 6 * 6 * 3 image with the filter of 3 * 3 * 3 then we get the feature map of 4 * 4 with single channel.

# %% [markdown]
# **Multiple Filters:**
#
# It will never happen like you will be using only single filter in your CNN architecture convolution process.There will be multiple filters for example,vertical edge filter,horizintal edge filter,slant edge filter etc.
#
# ![1.jpg](data:image/jpeg;base64,...)
#
#
#
# Observe here in Above convolution process,two different filters 1)Vertical Edge Filter and 2) Horizintal Edge Filter is used so we ot two different feature maps of size 4 * 4 of single channel.Now these two different feature maps can be considered as a volume for giput to the next layer.
