# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKPARATKAR/DEEP-LEARNING-WORK/blob/main/Self_AttentionInTransformers_GeomentricIntuition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# We have sentence "money bank" and we have to calculate the contextual word embedding of the both words in the sentence.1st we calculated the word embeddings of both the vectors,then multiplied it with tress vectors which was initialized by random values to get 3 different vectors for key , query and value.These thress vectors of key , query and value will be used to calculate the final contextual word embedding of the perticular word according to the dataset we are using and task we are performing.

# %% [markdown]
# **Step 1)**
#
# Below is the calculation of 3 vectors for value , key and query for both the words money and bank.wq,wk and wv are randomly initialized matrix to calculate the key , query and value metrices of the word embeddings.After multiplication we will get the three different vectors which will perform different taks for that perticular word in calculaton of the contextual word embeddings.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Step 2)**
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Point to notice here is that when we draw the word embeddings of the both words,they were at higher angle which means in different direction.But when we applied contextual word embeddings on both the words , the angle between vectors of both contextual word embedding vector was small and they were at smaller angle.The reason of smaller angle is because contextual word embedding understands the context and similarity and accordingly find our the word embeddings.
