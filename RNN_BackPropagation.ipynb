# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKPARATKAR/DEEP-LEARNING-WORK/blob/main/RNN_BackPropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **RNN - Backpropagation -**
#
# In  RNN , backpropagation is called as Backpropagation through time[BPTT].
#
# We will consider a many to one RNN architecture of RNN  where sentiment analysis problem is there.We are classifying input of sentence in 0 or 1. We have a text input and we have a sentiment output. We have to convert input text into vectors, for that we wll calculate the number of unique words in the input dataset and write the sentences with those unique words.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Now we will draw RNN architecture and feed this data in the RNN.We have 1 hidden layer consisting of 3 units/cells. Input is 3 dimentional.Each input is going to the each hidden unit making a 3 * 3 weights . All 3 units will give output which is also the input for itself and other two units in next time step so these are 3 * 3 weights. And the output of each hidden unit is going to the output layer so these 3 weights. In total we have 3 * 3 + 3 * 3 + 3 = 21 weight values.We have 3 bias in hidden layer and 1 bias at output layer.
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Forward propagation in this architecture to calculate the yhat and subsequently the loss of the system is as follows:
#
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# After forward propagation , we will have the loss value of the model. We need to find the best values of parameters like (wi,wh,wo) so that the loss function is minimum. We will use gradient descent algorithm to find the best values of parameters.
#
# ![1.jpg](data:image/jpeg;base64,...)
#
# Our aim is to calculate these 3  derivative boxed in blue color.

# %% [markdown]
# So calculating these three derivative is not the easy task because loss function L is dependant onmultiple things at the same time . We will get some 10 more derviatives to calculate to find the delL by delwi. So after calculating these derivatives we can update  the weight values and continue this process till we get minimum values of wi , wh and wo.
#
#  Refer the nodes -- https://d502jbuhuh9wk.cloudfront.net/digital_products/63720d30e4b06ff06d1f4547/65dc0a44d4b41516c968e20f/asset/1725958466053/file.pdf  (Page no 247)
